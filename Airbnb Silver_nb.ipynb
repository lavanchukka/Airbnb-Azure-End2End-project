# %% [markdown]
# ## Application registration details
# ### App id : cf24ddc3-8daf-409f-8279-317606778594
# ### object id : 889f9083-f489-4775-b42b-fe60571a569b
# ### directory id : 1d04dbbc-103e-4552-bfc3-8136fbd2e8fc
# ### secret value: 9hZxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %% [markdown]
# ### Connect Databricks to datalake

# %%
spark.conf.set(
    "fs.azure.account.auth.type.airbnbstoreacc.dfs.core.windows.net",
    "OAuth"
)
spark.conf.set(
    "fs.azure.account.oauth2.client.id.airbnbstoreacc.dfs.core.windows.net",
    "cf24ddc3-8daf-409f-8279-317606778594"
)
spark.conf.set(
    "fs.azure.account.oauth2.client.secret.airbnbstoreacc.dfs.core.windows.net",
    "9hZ8Q~GutipAq6BZcSap3XraUVQnV3CZHMU6mdz6"
)
spark.conf.set(
    "fs.azure.account.oauth2.client.endpoint.airbnbstoreacc.dfs.core.windows.net",
    "https://login.microsoftonline.com/1d04dbbc-103e-4552-bfc3-8136fbd2e8fc/oauth2/token"
)

# %% [markdown]
# import functions and types

# %%
#import functions and data types
from pyspark.sql.functions import*
from pyspark.sql.types import*

# %%
#load data from bronze layer
df_rawairbnb = spark.read.format("csv").option("header", "true").load('abfss://bronze@airbnbstoreacc.dfs.core.windows.net/airbnb')

# %%
#display the data 
df_rawairbnb.display()

# %%
# write data inparquet format to silver layer
df_rawairbnb.write.format("parquet").mode("append").save("abfss://silver@airbnbstoreacc.dfs.core.windows.net/airbnbsilver")
